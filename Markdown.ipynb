# %% [markdown]
# # Мой проект
#
# > Краткое описание
#
# ## Содержание
#
# <!-- TOC -->
# - [Введение](#введение)
# - [Установка](#установка)
# - [Диаграмма](#диаграмма)
# <!-- /TOC -->
#
# ## Введение
#
# Это документация по проекту.
#
# ## Диаграмма
